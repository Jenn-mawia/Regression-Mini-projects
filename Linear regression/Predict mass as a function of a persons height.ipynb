# %% [markdown]
# # **Objective:**
#
# **Create a simple linear regression model that predicts weight as a function of height.**
#
# The given dataset contains average masses of women as a function of their height in a sample of American women between 30-39 years of age.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
mass = pd.read_csv("http://bit.ly/HeightsandWeightsDataset")
mass
